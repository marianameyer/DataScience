# %% [markdown]
# <a href="https://colab.research.google.com/github/marianameyer/DataScience/blob/main/3_Minicurso_Analise_de_Dados_Python_Dados_Cartao_Credito.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desafio:
#
# Você trabalha em uma grande empresa de Cartão de Crédito e o diretor da empresa percebeu que o número de clientes que cancelam seus cartões tem aumentado significativamente, causando prejuízos enormes para a empresa
#
# O que fazer para evitar isso? Como saber as pessoas que têm maior tendência a cancelar o cartão?
#
# # O que temos:
#
# Temos 1 base de dados com informações dos clientes, tanto clientes atuais quanto clientes que cancelaram o cartão
#
# Download da Base de Dados: Botão na página
#
# Referência: https://www.kaggle.com/sakshigoyal7/credit-card-customers

# %% [markdown]
# # Importando as Bibliotecas e Carregando o DF

# %%
# Montando o Drive para usar o Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importando bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Carregando o df
df = pd.read_csv('/content/drive/MyDrive/Material de Cursos/Minicurso Análise de Dados - Hashtag/ClientesBanco.csv', encoding='ISO-8859-1')

# %% [markdown]
# # Visualização Prévia dos Dados

# %%
# Visualização do df
df.head()
# Out:
#    CLIENTNUM Categoria  Idade Sexo  Dependentes           Educação  \
# 0  768805383   Cliente     45    M            3       Ensino Médio
# 1  818770008   Cliente     49    F            5    Ensino Superior
# 2  713982108   Cliente     51    M            3    Ensino Superior
# 3  769911858   Cliente     40    F            4       Ensino Médio
# 4  709106358   Cliente     40    M            3  Sem ensino formal
#
#     Estado Civil Faixa Salarial Anual Categoria Cartão  Meses como Cliente  \
# 0         Casado          $60K - $80K             Blue                  39
# 1       Solteiro       Less than $40K             Blue                  44
# 2         Casado         $80K - $120K             Blue                  36
# 3  Não informado       Less than $40K             Blue                  34
# 4         Casado          $60K - $80K             Blue                  21
#
#    ...  Inatividade 12m  Contatos 12m   Limite  Limite Consumido  \
# ...

# %%
# Dados estatísticos do df
df.describe()
# Out:
#           CLIENTNUM         Idade   Dependentes  Meses como Cliente  \
# count  1.012700e+04  10127.000000  10127.000000        10127.000000
# mean   7.391776e+08     46.325960      2.346203           35.928409
# std    3.690378e+07      8.016814      1.298908            7.986416
# min    7.080821e+08     26.000000      0.000000           13.000000
# 25%    7.130368e+08     41.000000      1.000000           31.000000
# 50%    7.179264e+08     46.000000      2.000000           36.000000
# 75%    7.731435e+08     52.000000      3.000000           40.000000
# max    8.283431e+08     73.000000      5.000000           56.000000
#
#        Produtos Contratados  Inatividade 12m  Contatos 12m        Limite  \
# count          10127.000000     10127.000000  10127.000000  10127.000000
# mean               3.812580         2.341167      2.455317   8631.953698
# std                1.554408         1.010622      1.106225   9088.776650
# ...

# %%
# Informações úteis do df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CLIENTNUM                      10127 non-null  int64
#  1   Categoria                      10127 non-null  object
#  2   Idade                          10127 non-null  int64
#  3   Sexo                           10127 non-null  object
#  4   Dependentes                    10127 non-null  int64
#  5   Educação                       10127 non-null  object
#  6   Estado Civil                   10127 non-null  object
#  7   Faixa Salarial Anual           10127 non-null  object
#  8   Categoria Cartão               10126 non-null  object
#  9   Meses como Cliente             10127 non-null  int64
#  10  Produtos Contratados           10127 non-null  int64
#  11  Inatividade 12m                10127 non-null  int64
# ...

# %% [markdown]
# # "Arrumando" nosso DF
#
# Iremos excluir dados/colunas que não agregam informação para a resolução do problema proposto.

# %%
# Exclusão da coluna CLIENTNUM 
df = df.drop('CLIENTNUM', axis=1)
df.head()
# Out:
#   Categoria  Idade Sexo  Dependentes           Educação   Estado Civil  \
# 0   Cliente     45    M            3       Ensino Médio         Casado
# 1   Cliente     49    F            5    Ensino Superior       Solteiro
# 2   Cliente     51    M            3    Ensino Superior         Casado
# 3   Cliente     40    F            4       Ensino Médio  Não informado
# 4   Cliente     40    M            3  Sem ensino formal         Casado
#
#   Faixa Salarial Anual Categoria Cartão  Meses como Cliente  \
# 0          $60K - $80K             Blue                  39
# 1       Less than $40K             Blue                  44
# 2         $80K - $120K             Blue                  36
# 3       Less than $40K             Blue                  34
# 4          $60K - $80K             Blue                  21
#
#    Produtos Contratados  Inatividade 12m  Contatos 12m   Limite  \
# 0                     5                1             3  12691.0
# ...

# %% [markdown]
# Não encontrei colunas com muitos valores NaN ou que não fossem pertinentes ao problema proposto. A única exclusão é um valor faltante na coluna 'Categoria Cartão'.
#
# Como falta um dado (de uma única linha) em um df com 10127 dados, excluirei essa linha.

# %%
# Exclusão de linha em que falta dado
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10126 entries, 0 to 10126
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Categoria                      10126 non-null  object
#  1   Idade                          10126 non-null  int64
#  2   Sexo                           10126 non-null  object
#  3   Dependentes                    10126 non-null  int64
#  4   Educação                       10126 non-null  object
#  5   Estado Civil                   10126 non-null  object
#  6   Faixa Salarial Anual           10126 non-null  object
#  7   Categoria Cartão               10126 non-null  object
#  8   Meses como Cliente             10126 non-null  int64
#  9   Produtos Contratados           10126 non-null  int64
#  10  Inatividade 12m                10126 non-null  int64
#  11  Contatos 12m                   10126 non-null  int64
# ...

# %%
# Nova visualização dos dados estatísticos com os dados que serão usados
df.describe()
# Out:
#               Idade   Dependentes  Meses como Cliente  Produtos Contratados  \
# count  10126.000000  10126.000000        10126.000000          10126.000000
# mean      46.327079      2.346139           35.928995              3.812463
# std        8.016420      1.298956            7.986593              1.554440
# min       26.000000      0.000000           13.000000              1.000000
# 25%       41.000000      1.000000           31.000000              3.000000
# 50%       46.000000      2.000000           36.000000              4.000000
# 75%       52.000000      3.000000           40.000000              5.000000
# max       73.000000      5.000000           56.000000              6.000000
#
#        Inatividade 12m  Contatos 12m        Limite  Limite Consumido  \
# count     10126.000000  10126.000000  10126.000000      10126.000000
# mean          2.341300      2.455264   8631.962088       1162.764369
# std           1.010584      1.106267   9089.225428        815.012238
# ...

# %% [markdown]
# # Análises:

# %% [markdown]
# ## Relação entre Clientes e Cancelados:

# %%
# Verificação de quantos valores distintos há na coluna 'Categoria'
qt_clientes = df['Categoria'].value_counts()
qt_clientes
# Out:
# Cliente      8499
# Cancelado    1627
# Name: Categoria, dtype: int64

# %%
# Faremos o mesmo para obter o percentual de clientes e cancelados
qt_clientes_p = df['Categoria'].value_counts(normalize=True)
qt_clientes_p
# Out:
# Cliente      0.839325
# Cancelado    0.160675
# Name: Categoria, dtype: float64
